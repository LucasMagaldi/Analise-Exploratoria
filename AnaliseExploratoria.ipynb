# %%
import pandas as pd
# %matplotlib inline
# %pylab inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import sys
reload(sys)
sys.setdefaultencoding('utf8')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-104fb4b2204b> in <module>
#       1 import sys
# ----> 2 reload(sys)
#       3 sys.setdefaultencoding('utf8')
#
# NameError: name 'reload' is not defined

# %% [markdown]
# # carregando base de dados

# %%
df = pd.read_csv('2_semestre_2016.csv', sep=';', encoding='latin1')

# %%
df.tail()
# Out:
#        Região  UF          Cidade Sexo        Faixa Etária Data Finalização  \
# 162579     SE  ES      Vila Velha    M  entre 21 a 30 anos       02/12/2016
# 162580     SE  SP          Franca    F  entre 31 a 40 anos       01/12/2016
# 162581     SE  SP       São Paulo    F  entre 51 a 60 anos       01/12/2016
# 162582     NE  MA  Paço do Lumiar    M  entre 41 a 50 anos       02/12/2016
# 162583     N   RO     Porto Velho    F  entre 51 a 60 anos       07/12/2016
#
#         Tempo Resposta    Nome Fantasia  \
# 162579             9.0    Claro Celular
# 162580             NaN              Tim
# 162581             7.0  Banco do Brasil
# 162582            10.0       Oi Celular
# 162583            10.0          Oi Fixo
#
#                                       Segmento de Mercado  \
# 162579  Operadoras de Telecomunicações (Telefonia, Int...
# 162580  Operadoras de Telecomunicações (Telefonia, Int...
# 162581    Bancos, Financeiras e Administradoras de Cartão
# ...

# %%
df.describe()
# Out:
#        Tempo Resposta  Nota do Consumidor     Total
# count   161993.000000        95118.000000  162584.0
# mean         6.440247            3.320108       1.0
# std          3.378037            1.696041       0.0
# min          0.000000            1.000000       1.0
# 25%          3.000000            1.000000       1.0
# 50%          8.000000            4.000000       1.0
# 75%          9.000000            5.000000       1.0
# max         12.000000            5.000000       1.0

# %%
df['Segmento de Mercado'].unique()
# Out:
# array(['Operadoras de Telecomunicações (Telefonia, Internet, TV por assinatura)',
#        'Bancos de Dados e Cadastros de Consumidores', 'Transporte Aéreo',
#        'Bancos, Financeiras e Administradoras de Cartão',
#        'Agências de Viagens', 'Perfumaria, Cosméticos e Higiene Pessoal',
#        'Fabricantes - Linha Branca', 'Administradoras de Consórcios',
#        'Varejo',
#        'Fabricantes - Eletroeletrônicos,  Produtos de Telefonia e Informática',
#        'Programas de Fidelidade', 'Energia Elétrica, Gás, Água e Esgoto',
#        'Operadoras de Planos de Saúde e Administradoras de Benefícios',
#        'Provedores de Conteúdo e Outros Serviços na Internet',
#        'Comércio Eletrônico',
#        'Fabricantes - Eletroportáteis e Artigos de Uso Doméstico e Pessoal',
#        'Corretoras e Sociedades de Seguros, Capitalização e Previdência',
#        'Empresas de Recuperação de Crédito', 'Supermercados', 'Farmácias',
# ...

# %%
df.groupby(by ='UF')['UF'].count()
# Out:
# UF
# AC      554
# AL      647
# AM     1026
# AP      173
# BA     8269
# CE     5362
# DF     7057
# ES     3612
# GO     4355
# MA     1572
# MG    14356
# MS     1548
# MT     4108
# PA     1721
# PB     1586
# PE     4192
# PI      908
# PR    15107
# RJ    16895
# RN     1238
# RO      565
# RR      220
# RS    14615
# SC     4898
# SE      750
# SP    44905
# TO     2345
# Name: UF, dtype: int64

# %%
df['Sexo'].value_counts()
# Out:
# M    95462
# F    67122
# Name: Sexo, dtype: int64

# %%
df['Sexo'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %% [markdown]
# # Quantidade de reclamações por sexo

# %%
import seaborn as sea
sea.set(style='darkgrid')

# %%
sexo = df['Sexo'].unique()
cont = df['Sexo'].value_counts()
sea.barplot(x=sexo, y=cont)
# Out:
# <AxesSubplot:ylabel='Sexo'>

# %% [markdown]
# # Faixa etaria de consumidores por sexo

# %%
df.groupby('Sexo')['Faixa Etária'].value_counts()
# Out:
# Sexo  Faixa Etária
# F     entre 21 a 30 anos    20470
#       entre 31 a 40 anos    19617
#       entre 41 a 50 anos    10626
#       entre 51 a 60 anos     8306
#       entre 61 a 70 anos     4242
#       até 20 anos            1958
#       mais de 70 anos        1903
# M     entre 21 a 30 anos    33597
#       entre 31 a 40 anos    31049
#       entre 41 a 50 anos    13501
#       entre 51 a 60 anos     8171
#       entre 61 a 70 anos     4260
#       até 20 anos            3170
#       mais de 70 anos        1714
# Name: Faixa Etária, dtype: int64

# %%
comoComprou = df[df['Como Comprou Contratou'] == 'Internet']
z = comoComprou.groupby('Faixa Etária')['Como Comprou Contratou'].value_counts()
z.plot.barh()
# Out:
# <AxesSubplot:ylabel='Faixa Etária,Como Comprou Contratou'>

# %% [markdown]
# # Estes consumidores procuram a empresa antes da reclamação?

# %%
entre20e30 = df[df['Faixa Etária'] == 'entre 21 a 30 anos']
entre20e30['Procurou Empresa'].value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Problemas mais recorrentes

# %%
df['Grupo Problema'].value_counts()
# Out:
# Cobrança / Contestação    67074
# Contrato / Oferta         29460
# Vício de Qualidade        20832
# Atendimento / SAC         19883
# Informação                18322
# Entrega do Produto         6403
# Saúde e Segurança           610
# Name: Grupo Problema, dtype: int64

# %%
df[df['Grupo Problema'] == 'Cobrança / Contestação']['Segmento de Mercado'].value_counts()
# Out:
# Operadoras de Telecomunicações (Telefonia, Internet, TV por assinatura)    36106
# Bancos, Financeiras e Administradoras de Cartão                            21829
# Comércio Eletrônico                                                         3144
# Bancos de Dados e Cadastros de Consumidores                                  998
# Transporte Aéreo                                                             733
# Energia Elétrica, Gás, Água e Esgoto                                         691
# Empresas de Recuperação de Crédito                                           597
# Varejo                                                                       553
# Operadoras de Planos de Saúde e Administradoras de Benefícios                406
# Perfumaria, Cosméticos e Higiene Pessoal                                     404
# Corretoras e Sociedades de Seguros, Capitalização e Previdência              384
# Agências de Viagens                                                          381
# ...

# %%
 df[df['Grupo Problema'] == 'Contrato / Oferta']['Segmento de Mercado'].value_counts()
# Out:
# Operadoras de Telecomunicações (Telefonia, Internet, TV por assinatura)    15710
# Bancos, Financeiras e Administradoras de Cartão                             5471
# Comércio Eletrônico                                                         3686
# Bancos de Dados e Cadastros de Consumidores                                  995
# Transporte Aéreo                                                             566
# Fabricantes - Eletroeletrônicos,  Produtos de Telefonia e Informática        536
# Corretoras e Sociedades de Seguros, Capitalização e Previdência              507
# Programas de Fidelidade                                                      423
# Varejo                                                                       407
# Agências de Viagens                                                          233
# Supermercados                                                                201
# Operadoras de Planos de Saúde e Administradoras de Benefícios                191
# ...

# %% [markdown]
# # Grupo de problemas mais recorrentes

# %%
segmento = df[df['Grupo Problema'] == 'Cobrança / Contestação']
segmento['Segmento de Mercado'].value_counts()
# Out:
# Operadoras de Telecomunicações (Telefonia, Internet, TV por assinatura)    36106
# Bancos, Financeiras e Administradoras de Cartão                            21829
# Comércio Eletrônico                                                         3144
# Bancos de Dados e Cadastros de Consumidores                                  998
# Transporte Aéreo                                                             733
# Energia Elétrica, Gás, Água e Esgoto                                         691
# Empresas de Recuperação de Crédito                                           597
# Varejo                                                                       553
# Operadoras de Planos de Saúde e Administradoras de Benefícios                406
# Perfumaria, Cosméticos e Higiene Pessoal                                     404
# Corretoras e Sociedades de Seguros, Capitalização e Previdência              384
# Agências de Viagens                                                          381
# ...

# %%
plt.style.use('ggplot')
plt.rcdefaults()
fig, ax = plt.subplots()

y_pos=np.arange(len(segmento['Segmento de Mercado'].value_counts()))
values = segmento['Segmento de Mercado'].value_counts()
segmentos = segmento['Segmento de Mercado'].unique()

ax.barh(y_pos, values, align = 'center', color = 'blue')
ax.set_yticks(y_pos)
ax.set_yticklabels(segmentos)
ax.invert_yaxis()
ax.set_xlabel('Reclamações')
ax.set_title('Cobrança e Contestação por Segmento de Mercado')
plt.show()

# %% [markdown]
# # Top 20 empresas com maior numero de reclamações

# %%
fig, ax = plt.subplots()

y_pos = np.arange(len(segmento['Nome Fantasia'].value_counts()[:20]))
values = segmento['Nome Fantasia'].value_counts()[:20]
segmentos = segmento['Nome Fantasia'].unique()[:20]

ax.barh(y_pos, values, align = 'center', color = 'blue')
ax.set_yticks(y_pos)
ax.set_yticklabels(segmentos)
ax.invert_yaxis()
ax.set_xlabel('Reclamações')
ax.set_title('Rank das Empresas')

plt.show()

# %%
df.plot.density(y='Nota do Consumidor', xlim=[0,6])
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df.plot.density(y = 'Tempo Resposta', xlim = [0,11])
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # Proporção das reclamações registradas e não respondidas
